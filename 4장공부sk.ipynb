# %%
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_excel('C:/Users/pc/Desktop/2학년/데분/데분발표내꺼/데분 모든포지션 전처리 최종.xlsx', fillna='0', header=0)


df = df.fillna(method='ffill')
df.set_index('Name',inplace = True)
df
sr_one = df.loc['Harry Kane']


plt.plot(sr_one.index,sr_one.values)

# %%
import pandas as pd
import matplotlib.pyplot as plt

 
df = pd.read_excel('C:/Users/pc/Desktop/2학년/데분/데분발표내꺼/데분 모든포지션 전처리 최종.xlsx', fillna='0', header=0)


df = df.fillna(method='ffill')
df.set_index('Name',inplace = True)
sr_one = df['Gls']
sr_one = sr_one.sort_values(ascending = True)
sr_one.plot(kind = 'barh', figsize  = (100,100))
plt.show()

# %%
df
target = df['Market value']
target
df.regplot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Market value'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-3b33a986ba6a> in <module>
#       1 df
# ----> 2 target = df['Market value']
# ...

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns
import io


Boston = pd.read_csv('C:/Users/pc/Desktop/2학년/데분/BostonHousingData.csv')
feature_list = list(Boston.columns[:14])
features=Boston.iloc[:, :14]


plt.figure(figsize=(9,9))
sns.lmplot(x="DIS", y="NOX", data=features, line_kws={'color':"red"}, ci=None)
plt.show()
Boston.plot(kind = 'scatter', x = 'DIS', y = 'NOX')
plt.show()
