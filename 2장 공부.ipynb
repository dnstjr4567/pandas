# %%
import pandas as pd
boston = pd.read_csv('C:/Users/pc/Desktop/데분/BostonHousingData.csv')
print(boston)
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  \
# 0     0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296
# 1     0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242
# 2     0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242
# 3     0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222
# 4     0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222
# 5     0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222
# 6     0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311
# 7     0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311
# 8     0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311
# 9     0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311
# 10    0.22489  12.5   7.87     0  0.524  6.377   94.3  6.3467    5  311
# 11    0.11747  12.5   7.87     0  0.524  6.009   82.9  6.2267    5  311
# ...

# %%
dd = pd.read_excel('C:/Users/pc/Desktop/판다스터디/ss.xlsx')
dd
print(dd)
# Out:
#   Unnamed: 0    A1    A2    A3
# 0         B1  61.0  64.1  65.2
# 1         B2  60.2  63.2  66.1
# 2         B3  63.3  66.2  66.6
# 3         B4  62.7  65.4  67.2
# 4         B5  61.3  63.2  66.0
# 5         B6  61.9  64.2  66.4

# %%
dd
# Out:
#   Unnamed: 0    A1    A2    A3
# 0         B1  61.0  64.1  65.2
# 1         B2  60.2  63.2  66.1
# 2         B3  63.3  66.2  66.6
# 3         B4  62.7  65.4  67.2
# 4         B5  61.3  63.2  66.0
# 5         B6  61.9  64.2  66.4

# %%
boston.head(10)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222     18.7
# 6  0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311     15.2
# 7  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311     15.2
# 8  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311     15.2
# 9  0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311     15.2
#
#         B  LSTAT  MEDV Class
# 0  396.90   4.98  24.0  High
# 1  396.90   9.14  21.6   Low
# ...

# %%
dd.tail(3)
# Out:
#   Unnamed: 0    A1    A2    A3
# 3         B4  62.7  65.4  67.2
# 4         B5  61.3  63.2  66.0
# 5         B6  61.9  64.2  66.4

# %%
dd2 = pd.read_excel('C:/Users/pc/Desktop/판다스터디/ss.xlsx', index_col = 0)#첫번째 열 이름 없으면 0으로 하는듯
dd2
# Out:
#       A1    A2    A3
# B1  61.0  64.1  65.2
# B2  60.2  63.2  66.1
# B3  63.3  66.2  66.6
# B4  62.7  65.4  67.2
# B5  61.3  63.2  66.0
# B6  61.9  64.2  66.4

# %%
df1 = pd.read_excel('C:/Users/pc/Desktop/판다스터디/5674-833_4th/part2/남북한발전전력량.xlsx',index_col ='전력량 (억㎾h)')  
df1
# Out:
#           발전 전력별  1990  1991  1992  1993  1994  1995  1996  1997  1998  ...  \
# 전력량 (억㎾h)                                                               ...
# 남한            합계  1077  1186  1310  1444  1650  1847  2055  2244  2153  ...
# NaN           수력    64    51    49    60    41    55    52    54    61  ...
# NaN           화력   484   573   696   803  1022  1122  1264  1420  1195  ...
# NaN          원자력   529   563   565   581   587   670   739   771   897  ...
# NaN          신재생     -     -     -     -     -     -     -     -     -  ...
# 북한            합계   277   263   247   221   231   230   213   193   170  ...
# NaN           수력   156   150   142   133   138   142   125   107   102  ...
# NaN           화력   121   113   105    88    93    88    88    86    68  ...
# NaN          원자력     -     -     -     -     -     -     -     -     -  ...
#
#            2007  2008  2009  2010  2011  2012  2013  2014  2015  2016
# 전력량 (억㎾h)
# ...
